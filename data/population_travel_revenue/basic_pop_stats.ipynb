# %%
# Data Source:
# https://www.census.gov/data/tables/time-series/demo/popest/2010s-total-cities-and-towns.html#tables

# %%
import pandas as pd

# %%
city_pop = pd.read_csv('SUB-IP-EST2019-ANNRNK.csv',
                       header=3
                      )
print(city_pop.shape)
city_pop.head()
# Out:
# (794, 14)
#   Rank               Geographic Area April 1, 2010      Unnamed: 3  \
# 0  NaN                           NaN        Census  Estimates Base
# 1    1       New York city, New York     8,175,133       8,175,031
# 2    2  Los Angeles city, California     3,792,621       3,793,139
# 3    3        Chicago city, Illinois     2,695,598       2,695,652
# 4    4           Houston city, Texas     2,099,451       2,095,517
#
#   Population Estimate (as of July 1) Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0                               2010       2011       2012       2013
# 1                          8,190,209  8,272,948  8,346,693  8,396,091
# 2                          3,795,512  3,820,876  3,851,202  3,881,622
# 3                          2,697,477  2,708,114  2,719,141  2,725,731
# 4                          2,100,280  2,126,032  2,161,593  2,199,391
#
#   Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13
# 0       2014       2015        2016        2017        2018        2019
# 1  8,433,806  8,463,049   8,469,153   8,437,478   8,390,081   8,336,817
# 2  3,909,901  3,938,568   3,963,226   3,975,788   3,977,596   3,979,576
# 3  2,727,066  2,724,344   2,716,723   2,711,069   2,701,423   2,693,976
# 4  2,241,826  2,286,908   2,309,544   2,316,750   2,318,573   2,320,268
