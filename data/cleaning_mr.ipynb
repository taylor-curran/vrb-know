# %%
import pandas as pd
import numpy as np

# %%
# master row
mr = pd.read_csv('giant_merge.csv', index_col=0)
# Out:
# /Users/taylorcurran/prj/2021/vrb-know/venv/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (2,3,4,5,10,12,13,18,19,20,21,22) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
mr.head()
# Out:
#    RegionID   RegionName State_x                           Metro   CountyName  \
# 0    6181.0     New York      NY                        New York       Queens
# 1   12447.0  Los Angeles      CA  Los Angeles-Long Beach-Anaheim  Los Angeles
# 2   46298.0   Long Beach      CA  Los Angeles-Long Beach-Anaheim  Los Angeles
# 3   45457.0     Glendale      CA  Los Angeles-Long Beach-Anaheim  Los Angeles
# 4    5534.0    Lancaster      CA  Los Angeles-Long Beach-Anaheim  Los Angeles
#
#    SizeRank  pct_change  2017-09         loc_full dest_state  ...  \
# 0       1.0    0.092089    483.0       Queens, NY        NaN  ...
# 1       2.0    0.080575    432.0  Los Angeles, CA        NaN  ...
# 2      34.0    0.068866    425.0  Los Angeles, CA        NaN  ...
# 3     122.0    0.059937    483.0  Los Angeles, CA        NaN  ...
# 4     138.0    0.119016    149.0  Los Angeles, CA        NaN  ...
#
#    Severe Ice Storm Severe Storm(s) Snow  Terrorist  Tornado  \
# ...

# %%
mr['State'].value_counts()[:5]
# Out:
# United States    12243
# Texas              254
# Georgia            159
# Virginia           134
# Kentucky           120
# Name: State, dtype: int64

# %%
mr['State_x'].isna().sum()

# %%
mr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18652 entries, 0 to 18651
# Data columns (total 46 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   RegionID                       12243 non-null  float64
#  1   RegionName                     12243 non-null  object
#  2   State_x                        12243 non-null  object
#  3   Metro                          11297 non-null  object
#  4   CountyName                     12243 non-null  object
#  5   SizeRank                       12243 non-null  float64
#  6   pct_change                     12242 non-null  float64
#  7   2017-09                        12243 non-null  float64
#  8   loc_full                       15510 non-null  object
#  9   dest_state                     3139 non-null   object
#  10  n_trips                        3139 non-null   float64
#  11  state_x                        3142 non-null   object
# ...

# %%
[['RegionName', 'State', 'Metro', 'pct_change', '2017-09', 'loc_full']]

# %%
mr['Coastal Storm'].nlargest(10)
# Out:
# 16257    4.0
# 16861    4.0
# 16997    4.0
# 18137    4.0
# 18139    4.0
# 18267    4.0
# 18526    4.0
# 15484    3.0
# 15491    3.0
# 15558    3.0
# Name: Coastal Storm, dtype: float64

# %%
mr.iloc[16257]
# Out:
# RegionID                                                      NaN
# RegionName                                                    NaN
# State_x                                                       NaN
# Metro                                                         NaN
# CountyName                                                    NaN
# SizeRank                                                      NaN
# pct_change                                                    NaN
# 2017-09                                                       NaN
# loc_full                         East Feliciana Parish, Louisiana
# dest_state                                                    NaN
# n_trips                                                       NaN
# state_x                                                       NaN
# State_y                                                       NaN
# State.Minimum.Wage                                            NaN
# ...

# %%
n_nans = []
for i in range(len(mr)):
    n_nans.append(mr.iloc[i].isna().sum())
    
mr.insert(46, 'n_nans', n_nans)

# %%
mr.sort_values(by='n_nans')
# Out:
#        RegionID RegionName State_x      Metro CountyName  SizeRank  \
# 0        6181.0   New York      NY   New York     Queens       1.0
# 7535    45536.0  Grapeview      WA    Shelton      Mason   10448.0
# 7536    19016.0  Lilliwaup      WA    Shelton      Mason   11388.0
# 7537    18618.0  Hoodsport      WA    Shelton      Mason   11904.0
# 7538    12186.0  Kerrville      TX  Kerrville       Kerr    1451.0
# ...         ...        ...     ...        ...        ...       ...
# 17278       NaN        NaN     NaN        NaN        NaN       NaN
# 16897       NaN        NaN     NaN        NaN        NaN       NaN
# 16901       NaN        NaN     NaN        NaN        NaN       NaN
# 18106       NaN        NaN     NaN        NaN        NaN       NaN
# 16576       NaN        NaN     NaN        NaN        NaN       NaN
#
#        pct_change  2017-09                         loc_full dest_state  ...  \
# 0        0.092089    483.0                       Queens, NY        NaN  ...
# ...

# %%
mr
