# %%
import pandas as pd

# %%
# Data Source
# https://data.world/zillow-data/median-home-value-per-sq-ft

data_path = 'zillow-data-median-home-value-per-sq-ft/City_MedianValuePerSqft_AllHomes.csv'
sqft = pd.read_csv(data_path)
print(sqft.shape)
sqft.head()
# Out:
# (12243, 264)
#    RegionID    RegionName State                           Metro    CountyName  \
# 0      6181      New York    NY                        New York        Queens
# 1     12447   Los Angeles    CA  Los Angeles-Long Beach-Anaheim   Los Angeles
# 2     17426       Chicago    IL                         Chicago          Cook
# 3     13271  Philadelphia    PA                    Philadelphia  Philadelphia
# 4     40326       Phoenix    AZ                         Phoenix      Maricopa
#
#    SizeRank  1996-04  1996-05  1996-06  1996-07  ...  2016-12  2017-01  \
# 0         1      NaN      NaN      NaN      NaN  ...    449.0      451
# 1         2    110.0    109.0    109.0    109.0  ...    414.0      415
# 2         3     94.0     94.0     93.0     93.0  ...    169.0      170
# 3         4     39.0     40.0     40.0     40.0  ...    101.0      101
# 4         5     58.0     58.0     58.0     58.0  ...    136.0      136
#
# ...

# %%
len(sqft.columns)
# Out:
# 264

# %%
col_array = pd.Series(sqft.columns)

# %%
col_array.head(10)
# Out:
# 0      RegionID
# 1    RegionName
# 2         State
# 3         Metro
# 4    CountyName
# 5      SizeRank
# 6       1996-04
# 7       1996-05
# 8       1996-06
# 9       1996-07
# dtype: object

# %%
col_array.tail()
# Out:
# 259    2017-05
# 260    2017-06
# 261    2017-07
# 262    2017-08
# 263    2017-09
# dtype: object

# %%
sm_sqft = sqft[['RegionID', 'RegionName', 'State', 
                'Metro', 'CountyName', 'SizeRank', 
                '2017-09']]

print(sm_sqft.shape)
sm_sqft.head()
# Out:
# (12243, 7)
#    RegionID    RegionName State                           Metro    CountyName  \
# 0      6181      New York    NY                        New York        Queens
# 1     12447   Los Angeles    CA  Los Angeles-Long Beach-Anaheim   Los Angeles
# 2     17426       Chicago    IL                         Chicago          Cook
# 3     13271  Philadelphia    PA                    Philadelphia  Philadelphia
# 4     40326       Phoenix    AZ                         Phoenix      Maricopa
#
#    SizeRank  2017-09
# 0         1      483
# 1         2      432
# 2         3      173
# 3         4      107
# 4         5      143

# %%
sm_sqft.tail()
# Out:
#        RegionID           RegionName State      Metro CountyName  SizeRank  \
# 12238    397531     Palmyra Township    PA        NaN      Wayne     12239
# 12239    398292  Town of Wrightstown    WI  Green Bay      Brown     12240
# 12240    398343               Urbana    NY    Corning    Steuben     12241
# 12241    398839               Angels    CA        NaN  Calaveras     12242
# 12242    737788      Lebanon Borough    NJ   New York  Hunterdon     12243
#
#        2017-09
# 12238      104
# 12239       99
# 12240       87
# 12241      190
# 12242      172

# %%
# TX 🤠
sm_sqft[sm_sqft['State'] == 'TX'].sort_values(['2017-09'])
# Out:
#        RegionID       RegionName State              Metro  CountyName  \
# 4671      37970    Colorado City    TX                NaN    Mitchell
# 5900      51481          Coleman    TX                NaN     Coleman
# 7478      28859            Olney    TX                NaN       Young
# 8466      20663         Stinnett    TX             Borger  Hutchinson
# 9247      55260          Wortham    TX                NaN   Freestone
# ...         ...              ...   ...                ...         ...
# 9683      34075  Southside Place    TX            Houston      Harris
# 7739      26518      Piney Point    TX            Houston      Harris
# 8791      14558  West Lake Hills    TX             Austin      Travis
# 2020      48098  University Park    TX  Dallas-Fort Worth      Dallas
# 10034     40626      Rollingwood    TX             Austin      Travis
#
#        SizeRank  2017-09
# 4671       4672       34
# 5900       5901       35
# 7478       7479       35
# ...

# %%
# Combine Above 
import pandas as pd
destinations = pd.read_csv('../travel_revenue/most_popular_trips.csv')

# %%
destinations.head()
# Out:
#    Unnamed: 0  origin_code  destination_code    n_trips origin_state_county  \
# 0      695469         6073              6037  9098075.0        ('6', '073')
# 1      638859         6037              6073  9098075.0        ('6', '037')
# 2      619983         6025              6073  4337119.0        ('6', '025')
# 3      695463         6073              6025  4337119.0        ('6', '073')
# 4      682885         6065              6037  4009696.0        ('6', '065')
#
#   destination_state_county              origin         destination
# 0             ('6', '037')    San Diego County  Los Angeles County
# 1             ('6', '073')  Los Angeles County    San Diego County
# 2             ('6', '073')     Imperial County    San Diego County
# 3             ('6', '025')    San Diego County     Imperial County
# 4             ('6', '037')    Riverside County  Los Angeles County
