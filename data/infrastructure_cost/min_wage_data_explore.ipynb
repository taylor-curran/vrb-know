# %%
# Data Source
# https://www.kaggle.com/lislejoem/us-minimum-wage-by-state-from-1968-to-2017?select=Minimum+Wage+Data.csv

# %%
import pandas as pd

# %%
data_path = 'Minimum Wage Data.csv'

min_wage = pd.read_csv(data_path, encoding="ISO-8859-1")

print(min_wage.shape)
min_wage.head()
# Out:
# (2862, 15)
#    Year       State  State.Minimum.Wage  State.Minimum.Wage.2020.Dollars  \
# 0  1968     Alabama             0.00000                             0.00
# 1  1968      Alaska             2.10000                            15.61
# 2  1968     Arizona             0.46800                             3.48
# 3  1968    Arkansas             0.15625                             1.16
# 4  1968  California             1.65000                            12.26
#
#    Federal.Minimum.Wage  Federal.Minimum.Wage.2020.Dollars  \
# 0                  1.15                               8.55
# 1                  1.15                               8.55
# 2                  1.15                               8.55
# 3                  1.15                               8.55
# 4                  1.15                               8.55
#
#    Effective.Minimum.Wage  Effective.Minimum.Wage.2020.Dollars  CPI.Average  \
# 0                    1.15                                 8.55         34.8
# ...

# %%
min_wage_2020 = min_wage[min_wage['Year'] == 2020]

# %%
min_wage_2020.sort_values(by=['State.Minimum.Wage']).head(15)
# Out:
#       Year           State  State.Minimum.Wage  \
# 2808  2020         Alabama                0.00
# 2852  2020       Tennessee                0.00
# 2850  2020  South Carolina                0.00
# 2833  2020     Mississippi                0.00
# 2827  2020       Louisiana                0.00
# 2845  2020        Oklahoma                2.00
# 2848  2020     Puerto Rico                5.08
# 2818  2020         Georgia                5.15
# 2861  2020         Wyoming                5.15
# 2853  2020           Texas                7.25
# 2843  2020    North Dakota                7.25
# 2838  2020   New Hampshire                7.25
# 2837  2020          Nevada                7.25
# 2860  2020       Wisconsin                7.25
# 2847  2020    Pennsylvania                7.25
#
#       State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 2808                             0.00                  7.25
# 2852                             0.00                  7.25
# ...
