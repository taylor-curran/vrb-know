# %%
import pandas as pd

# %%
disas = pd.read_csv('DisasterDeclarationsSummaries.csv'
                   )

print(disas.shape)
disas.head()
# Out:
# (60612, 23)
#   femaDeclarationString  disasterNumber state declarationType  \
# 0               DR-1-GA               1    GA              DR
# 1               DR-2-TX               2    TX              DR
# 2               DR-5-MT               5    MT              DR
# 3               DR-7-MA               7    MA              DR
# 4               DR-8-IA               8    IA              DR
#
#             declarationDate  fyDeclared incidentType  \
# 0  1953-05-02T00:00:00.000Z        1953      Tornado
# 1  1953-05-15T00:00:00.000Z        1953      Tornado
# 2  1953-06-06T00:00:00.000Z        1953        Flood
# 3  1953-06-11T00:00:00.000Z        1953      Tornado
# 4  1953-06-11T00:00:00.000Z        1953        Flood
#
#            declarationTitle  ihProgramDeclared  iaProgramDeclared  ...  \
# 0                   TORNADO                  0                  1  ...
# 1  TORNADO & HEAVY RAINFALL                  0                  1  ...
# ...

# %%
disas.tail()
# Out:
#       femaDeclarationString  disasterNumber state declarationType  \
# 60607            DR-4584-WA            4584    WA              DR
# 60608            DR-4584-WA            4584    WA              DR
# 60609            DR-4584-WA            4584    WA              DR
# 60610            DR-4584-WA            4584    WA              DR
# 60611            DR-4584-WA            4584    WA              DR
#
#                 declarationDate  fyDeclared incidentType  \
# 60607  2021-02-04T10:05:00.000Z        2021         Fire
# 60608  2021-02-04T10:05:00.000Z        2021         Fire
# 60609  2021-02-04T10:05:00.000Z        2021         Fire
# 60610  2021-02-04T10:05:00.000Z        2021         Fire
# 60611  2021-02-04T10:05:00.000Z        2021         Fire
#
#                         declarationTitle  ihProgramDeclared  \
# 60607  WILDFIRES AND STRAIGHT-LINE WINDS                  0
# 60608  WILDFIRES AND STRAIGHT-LINE WINDS                  0
# ...
