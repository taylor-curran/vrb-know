# %% [markdown]
# ## Read in Data

# %%
# Import Statements
import pandas as pd
import numpy as np

# %% [markdown]
# ### Master Row Data

# %%
# Read in Data

# Price Per Square Feet per [County, City, State, +More]
ppsft = pd.read_csv('property_value_cost/cols_price_per_sqft.csv', 
                    index_col=0)

# N Trips Ending per [County Name, State]
dest = pd.read_csv('travel_revenue/col_travel_n_times_city_is_dest_with_states.csv')

# Minimum Wage per [State]
min_wg = pd.read_csv('infrastructure_cost/cols_infra_min_wage.csv', 
                     index_col=0)

# Property Taxes per [State]
prp_taxes = pd.read_csv('taxes_cost/18_revenue_state_and_local_summary.csv')

# Natural Disasters by Type per [County Name, State]
dis = pd.read_csv('nat_disasters_cost/cols_disaster_stats.csv')

# %%
print(ppsft.shape)
ppsft.head()
# Out:
# (12243, 8)
#    RegionID    RegionName State                           Metro    CountyName  \
# 0      6181      New York    NY                        New York        Queens
# 1     12447   Los Angeles    CA  Los Angeles-Long Beach-Anaheim   Los Angeles
# 2     17426       Chicago    IL                         Chicago          Cook
# 3     13271  Philadelphia    PA                    Philadelphia  Philadelphia
# 4     40326       Phoenix    AZ                         Phoenix      Maricopa
#
#    SizeRank  pct_change  2017-09
# 0         1    0.092089      483
# 1         2    0.080575      432
# 2         3    0.046394      173
# 3         4    0.078478      107
# 4         5    0.082650      143

# %%
print(dest.shape)
dest.head()
# Out:
# (3139, 3)
#                           dest_full      dest_state    n_trips
# 0  Abbeville County, South Carolina  South Carolina   184624.0
# 1          Acadia Parish, Louisiana       Louisiana   241374.0
# 2         Accomack County, Virginia        Virginia   242825.0
# 3                 Ada County, Idaho           Idaho  1964790.0
# 4                Adair County, Iowa            Iowa    69708.0

# %%
print(min_wg.shape)
min_wg.head()
# Out:
# (54, 5)
#            State  State.Minimum.Wage  Federal.Minimum.Wage  \
# 2808     Alabama                0.00                  7.25
# 2809      Alaska               10.19                  7.25
# 2810     Arizona               12.00                  7.25
# 2811    Arkansas               10.00                  7.25
# 2812  California               13.00                  7.25
#
#       Effective.Minimum.Wage  CPI.Average
# 2808                    7.25       258.66
# 2809                   10.19       258.66
# 2810                   12.00       258.66
# 2811                   10.00       258.66
# 2812                   13.00       258.66

# %%
print(prp_taxes.shape)
prp_taxes.head()
# Out:
# (52, 5)
#            State Total (millions of dollars) Per Capita (dollars)  \
# 0  United States                    $547,039               $1,667
# 1        Alabama                        2921                  596
# 2         Alaska                        1614                 2206
# 3        Arizona                        8053                 1106
# 4       Arkansas                        2334                  774
#
#   Percentage of General Revenue Percentage of Personal Income
# 0                         16.6%                          3.1%
# 1                          7.0%                          1.4%
# 2                         14.0%                          3.6%
# 3                         14.7%                          2.5%
# 4                          9.0%                          1.8%

# %%
print(dis.shape)
dis.head()
# Out:
# (3267, 24)
#                            loc_full  Biological  Chemical  Coastal Storm  \
# 0  Abbeville County, South Carolina         2.0       NaN            NaN
# 1          Acadia Parish, Louisiana         2.0       NaN            2.0
# 2         Accomack County, Virginia         2.0       NaN            NaN
# 3                 Ada County, Idaho         2.0       NaN            NaN
# 4                Adair County, Iowa         2.0       NaN            NaN
#
#    Dam/Levee Break  Drought  Earthquake  Fire  Fishing Losses  Flood  ...  \
# 0              NaN      1.0         NaN   NaN             NaN    1.0  ...
# 1              NaN      NaN         NaN   NaN             NaN    3.0  ...
# 2              NaN      NaN         NaN   NaN             NaN    2.0  ...
# 3              NaN      NaN         NaN   1.0             NaN    2.0  ...
# 4              NaN      NaN         NaN   NaN             NaN    4.0  ...
#
#    Other  Severe Ice Storm  Severe Storm(s)  Snow  Terrorist  Tornado  \
# 0    NaN               1.0              2.0   NaN        NaN      1.0
# 1    1.0               NaN              4.0   NaN        NaN      NaN
# 2    NaN               NaN              2.0   2.0        NaN      NaN
# 3    NaN               NaN              NaN   NaN        NaN      NaN
# 4    NaN               2.0              6.0   1.0        NaN      NaN
#
#    Toxic Substances  Tsunami  Typhoon  Volcano
# 0               NaN      NaN      NaN      NaN
# 1               NaN      NaN      NaN      NaN
# 2               NaN      NaN      NaN      NaN
# 3               NaN      NaN      NaN      NaN
# 4               NaN      NaN      NaN      NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Join Tables

# %%
# State Abbreviations + State Fips + State Name
states = pd.read_csv('join_tables/StatesFIPSCodes.csv')

# %%
print(states.shape)
states.head()
# Out:
# (57, 4)
#    STATE_FIPS STUSAB  STATE_NAME  STATENS
# 0           1     AL     Alabama  1779775
# 1           2     AK      Alaska  1785533
# 2           4     AZ     Arizona  1779777
# 3           5     AR    Arkansas    68085
# 4           6     CA  California  1779778

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Price Per Square Foot `ppsft`

# %%
ppsft.head(2)
# Out:
#    RegionID   RegionName State                           Metro   CountyName  \
# 0      6181     New York    NY                        New York       Queens
# 1     12447  Los Angeles    CA  Los Angeles-Long Beach-Anaheim  Los Angeles
#
#    SizeRank  pct_change  2017-09
# 0         1    0.092089      483
# 1         2    0.080575      432

# %%
ppsft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12243 entries, 0 to 12242
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   RegionID    12243 non-null  int64
#  1   RegionName  12243 non-null  object
#  2   State       12243 non-null  object
#  3   Metro       11297 non-null  object
#  4   CountyName  12243 non-null  object
#  5   SizeRank    12243 non-null  int64
#  6   pct_change  12242 non-null  float64
#  7   2017-09     12243 non-null  int64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 860.8+ KB

# %%
# Stick Together loc_full Column
loc_full = []
for i, row in ppsft.iterrows():
    loc_full.append(row[4] + ', ' + row[2])

ppsft.insert(8, 'loc_full', loc_full)

# %%
ppsft.head()
# Out:
#    RegionID    RegionName State                           Metro    CountyName  \
# 0      6181      New York    NY                        New York        Queens
# 1     12447   Los Angeles    CA  Los Angeles-Long Beach-Anaheim   Los Angeles
# 2     17426       Chicago    IL                         Chicago          Cook
# 3     13271  Philadelphia    PA                    Philadelphia  Philadelphia
# 4     40326       Phoenix    AZ                         Phoenix      Maricopa
#
#    SizeRank  pct_change  2017-09          loc_full
# 0         1    0.092089      483        Queens, NY
# 1         2    0.080575      432   Los Angeles, CA
# 2         3    0.046394      173          Cook, IL
# 3         4    0.078478      107  Philadelphia, PA
# 4         5    0.082650      143      Maricopa, AZ

# %% [markdown]
# ### Destination Trip Data `dest`

# %%
dest.head(2)
# Out:
#                           dest_full      dest_state   n_trips
# 0  Abbeville County, South Carolina  South Carolina  184624.0
# 1          Acadia Parish, Louisiana       Louisiana  241374.0

# %%
states.head()
# Out:
#    STATE_FIPS STUSAB  STATE_NAME  STATENS
# 0           1     AL     Alabama  1779775
# 1           2     AK      Alaska  1785533
# 2           4     AZ     Arizona  1779777
# 3           5     AR    Arkansas    68085
# 4           6     CA  California  1779778

# %%
dest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3139 entries, 0 to 3138
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   dest_full   3139 non-null   object
#  1   dest_state  3139 non-null   object
#  2   n_trips     3139 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 73.7+ KB

# %%
# Get State Column
state = []
for i, row in dest.iterrows():
    state_row = states[row[1] == states['STATE_NAME']]
    state.append(state_row['STUSAB'].values[0])

dest.insert(3, 'state', state)

# %%
dest.head()
# Out:
#                           dest_full      dest_state    n_trips state
# 0  Abbeville County, South Carolina  South Carolina   184624.0    SC
# 1          Acadia Parish, Louisiana       Louisiana   241374.0    LA
# 2         Accomack County, Virginia        Virginia   242825.0    VA
# 3                 Ada County, Idaho           Idaho  1964790.0    ID
# 4                Adair County, Iowa            Iowa    69708.0    IA

# %% [markdown]
# ### Minimum Wage `min_wg`

# %%
min_wg.head(2)
# Out:
#         State  State.Minimum.Wage  Federal.Minimum.Wage  \
# 2808  Alabama                0.00                  7.25
# 2809   Alaska               10.19                  7.25
#
#       Effective.Minimum.Wage  CPI.Average
# 2808                    7.25       258.66
# 2809                   10.19       258.66

# %%
min_wg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54 entries, 2808 to 2861
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   54 non-null     object
#  1   State.Minimum.Wage      54 non-null     float64
#  2   Federal.Minimum.Wage    54 non-null     float64
#  3   Effective.Minimum.Wage  54 non-null     float64
#  4   CPI.Average             54 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.5+ KB

# %%
# Get State Column
state = []
for i, row in min_wg.iterrows():
    state_row = states[row[0] == states['STATE_NAME']]
    state.append(state_row['STUSAB'].values[0])

min_wg.insert(5, 'state', state)

# %%
min_wg.head()
# Out:
#            State  State.Minimum.Wage  Federal.Minimum.Wage  \
# 2808     Alabama                0.00                  7.25
# 2809      Alaska               10.19                  7.25
# 2810     Arizona               12.00                  7.25
# 2811    Arkansas               10.00                  7.25
# 2812  California               13.00                  7.25
#
#       Effective.Minimum.Wage  CPI.Average state
# 2808                    7.25       258.66    AL
# 2809                   10.19       258.66    AK
# 2810                   12.00       258.66    AZ
# 2811                   10.00       258.66    AR
# 2812                   13.00       258.66    CA

# %% [markdown]
# ### Property Taxes `prp_taxes`

# %%
prp_taxes.head(2)
# Out:
#            State Total (millions of dollars) Per Capita (dollars)  \
# 0  United States                    $547,039               $1,667
# 1        Alabama                        2921                  596
#
#   Percentage of General Revenue Percentage of Personal Income
# 0                         16.6%                          3.1%
# 1                          7.0%                          1.4%

# %%
prp_taxes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 5 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   State                          52 non-null     object
#  1   Total (millions of dollars)    52 non-null     object
#  2   Per Capita (dollars)           52 non-null     object
#  3   Percentage of General Revenue  52 non-null     object
#  4   Percentage of Personal Income  52 non-null     object
# dtypes: object(5)
# memory usage: 2.2+ KB

# %%
# Get State Column
state = []
for i, row in prp_taxes.iterrows():
    state_row = states[row[0] == states['STATE_NAME']]
    try:
        state.append(state_row['STUSAB'].values[0])
    except:
        state.append(np.nan)
        
prp_taxes.insert(5, 'state', state)

# %%
prp_taxes.head(2)
# Out:
#            State Total (millions of dollars) Per Capita (dollars)  \
# 0  United States                    $547,039               $1,667
# 1        Alabama                        2921                  596
#
#   Percentage of General Revenue Percentage of Personal Income state
# 0                         16.6%                          3.1%   NaN
# 1                          7.0%                          1.4%    AL

# %% [markdown]
# ### Natural Disasters `dis`

# %%
dis.head(2)
# Out:
#                            loc_full  Biological  Chemical  Coastal Storm  \
# 0  Abbeville County, South Carolina         2.0       NaN            NaN
# 1          Acadia Parish, Louisiana         2.0       NaN            2.0
#
#    Dam/Levee Break  Drought  Earthquake  Fire  Fishing Losses  Flood  ...  \
# 0              NaN      1.0         NaN   NaN             NaN    1.0  ...
# 1              NaN      NaN         NaN   NaN             NaN    3.0  ...
#
#    Other  Severe Ice Storm  Severe Storm(s)  Snow  Terrorist  Tornado  \
# 0    NaN               1.0              2.0   NaN        NaN      1.0
# 1    1.0               NaN              4.0   NaN        NaN      NaN
#
#    Toxic Substances  Tsunami  Typhoon  Volcano
# 0               NaN      NaN      NaN      NaN
# 1               NaN      NaN      NaN      NaN
#
# [2 rows x 24 columns]

# %%
dis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3267 entries, 0 to 3266
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   loc_full          3267 non-null   object
#  1   Biological        3249 non-null   float64
#  2   Chemical          9 non-null      float64
#  3   Coastal Storm     474 non-null    float64
#  4   Dam/Levee Break   11 non-null     float64
#  5   Drought           1193 non-null   float64
#  6   Earthquake        168 non-null    float64
#  7   Fire              975 non-null    float64
#  8   Fishing Losses    34 non-null     float64
#  9   Flood             2705 non-null   float64
#  10  Freezing          171 non-null    float64
#  11  Human Cause       7 non-null      float64
#  12  Hurricane         2899 non-null   float64
#  13  Mud/Landslide     28 non-null     float64
#  14  Other             224 non-null    float64
#  15  Severe Ice Storm  995 non-null    float64
#  16  Severe Storm(s)   3042 non-null   float64
#  17  Snow              1623 non-null   float64
#  18  Terrorist         5 non-null      float64
#  19  Tornado           1096 non-null   float64
#  20  Toxic Substances  9 non-null      float64
#  21  Tsunami           9 non-null      float64
#  22  Typhoon           2 non-null      float64
#  23  Volcano           49 non-null     float64
# dtypes: float64(23), object(1)
# memory usage: 612.7+ KB

# %%
# Insert State Column
state = [s.split(',')[1].strip() for s in dis['loc_full']]
dis.insert(24, 'state', state)

# %%
dis.head()
# Out:
#                            loc_full  Biological  Chemical  Coastal Storm  \
# 0  Abbeville County, South Carolina         2.0       NaN            NaN
# 1          Acadia Parish, Louisiana         2.0       NaN            2.0
# 2         Accomack County, Virginia         2.0       NaN            NaN
# 3                 Ada County, Idaho         2.0       NaN            NaN
# 4                Adair County, Iowa         2.0       NaN            NaN
#
#    Dam/Levee Break  Drought  Earthquake  Fire  Fishing Losses  Flood  ...  \
# 0              NaN      1.0         NaN   NaN             NaN    1.0  ...
# 1              NaN      NaN         NaN   NaN             NaN    3.0  ...
# 2              NaN      NaN         NaN   NaN             NaN    2.0  ...
# 3              NaN      NaN         NaN   1.0             NaN    2.0  ...
# 4              NaN      NaN         NaN   NaN             NaN    4.0  ...
#
#    Severe Ice Storm  Severe Storm(s)  Snow  Terrorist  Tornado  \
# 0               1.0              2.0   NaN        NaN      1.0
# 1               NaN              4.0   NaN        NaN      NaN
# 2               NaN              2.0   2.0        NaN      NaN
# 3               NaN              NaN   NaN        NaN      NaN
# 4               2.0              6.0   1.0        NaN      NaN
#
#    Toxic Substances  Tsunami  Typhoon  Volcano           state
# 0               NaN      NaN      NaN      NaN  South Carolina
# 1               NaN      NaN      NaN      NaN       Louisiana
# 2               NaN      NaN      NaN      NaN        Virginia
# 3               NaN      NaN      NaN      NaN           Idaho
# 4               NaN      NaN      NaN      NaN            Iowa
#
# [5 rows x 25 columns]

# %% [markdown]
# ## The Join Begins!

# %%
ppsft.head()
# Out:
#    RegionID    RegionName State                           Metro    CountyName  \
# 0      6181      New York    NY                        New York        Queens
# 1     12447   Los Angeles    CA  Los Angeles-Long Beach-Anaheim   Los Angeles
# 2     17426       Chicago    IL                         Chicago          Cook
# 3     13271  Philadelphia    PA                    Philadelphia  Philadelphia
# 4     40326       Phoenix    AZ                         Phoenix      Maricopa
#
#    SizeRank  pct_change  2017-09          loc_full
# 0         1    0.092089      483        Queens, NY
# 1         2    0.080575      432   Los Angeles, CA
# 2         3    0.046394      173          Cook, IL
# 3         4    0.078478      107  Philadelphia, PA
# 4         5    0.082650      143      Maricopa, AZ

# %%
dest.head()
# Out:
#                           dest_full      dest_state    n_trips state
# 0  Abbeville County, South Carolina  South Carolina   184624.0    SC
# 1          Acadia Parish, Louisiana       Louisiana   241374.0    LA
# 2         Accomack County, Virginia        Virginia   242825.0    VA
# 3                 Ada County, Idaho           Idaho  1964790.0    ID
# 4                Adair County, Iowa            Iowa    69708.0    IA

# %%
merge1 = ppsft.merge(right=dest, how='outer', left_on='loc_full', right_on='dest_full')

# %%
merge1 = merge1.drop('dest_full', axis=1)

# %%
merge2 = merge1.merge(right=min_wg, how='outer', on='state')

# %%
merge2.head()
# Out:
#    RegionID   RegionName State_x                           Metro   CountyName  \
# 0    6181.0     New York      NY                        New York       Queens
# 1   12447.0  Los Angeles      CA  Los Angeles-Long Beach-Anaheim  Los Angeles
# 2   46298.0   Long Beach      CA  Los Angeles-Long Beach-Anaheim  Los Angeles
# 3   45457.0     Glendale      CA  Los Angeles-Long Beach-Anaheim  Los Angeles
# 4    5534.0    Lancaster      CA  Los Angeles-Long Beach-Anaheim  Los Angeles
#
#    SizeRank  pct_change  2017-09         loc_full dest_state  n_trips state  \
# 0       1.0    0.092089    483.0       Queens, NY        NaN      NaN   NaN
# 1       2.0    0.080575    432.0  Los Angeles, CA        NaN      NaN   NaN
# 2      34.0    0.068866    425.0  Los Angeles, CA        NaN      NaN   NaN
# 3     122.0    0.059937    483.0  Los Angeles, CA        NaN      NaN   NaN
# 4     138.0    0.119016    149.0  Los Angeles, CA        NaN      NaN   NaN
#
#   State_y  State.Minimum.Wage  Federal.Minimum.Wage  Effective.Minimum.Wage  \
# 0     NaN                 NaN                   NaN                     NaN
# 1     NaN                 NaN                   NaN                     NaN
# 2     NaN                 NaN                   NaN                     NaN
# 3     NaN                 NaN                   NaN                     NaN
# 4     NaN                 NaN                   NaN                     NaN
#
#    CPI.Average
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
merge3 = merge2.merge(right=prp_taxes, how='outer', on='state')

# %%
merge3.head()
# Out:
#    RegionID   RegionName State_x                           Metro   CountyName  \
# 0    6181.0     New York      NY                        New York       Queens
# 1   12447.0  Los Angeles      CA  Los Angeles-Long Beach-Anaheim  Los Angeles
# 2   46298.0   Long Beach      CA  Los Angeles-Long Beach-Anaheim  Los Angeles
# 3   45457.0     Glendale      CA  Los Angeles-Long Beach-Anaheim  Los Angeles
# 4    5534.0    Lancaster      CA  Los Angeles-Long Beach-Anaheim  Los Angeles
#
#    SizeRank  pct_change  2017-09         loc_full dest_state  ...  State_y  \
# 0       1.0    0.092089    483.0       Queens, NY        NaN  ...      NaN
# 1       2.0    0.080575    432.0  Los Angeles, CA        NaN  ...      NaN
# 2      34.0    0.068866    425.0  Los Angeles, CA        NaN  ...      NaN
# 3     122.0    0.059937    483.0  Los Angeles, CA        NaN  ...      NaN
# 4     138.0    0.119016    149.0  Los Angeles, CA        NaN  ...      NaN
#
#   State.Minimum.Wage Federal.Minimum.Wage  Effective.Minimum.Wage  \
# 0                NaN                  NaN                     NaN
# 1                NaN                  NaN                     NaN
# 2                NaN                  NaN                     NaN
# 3                NaN                  NaN                     NaN
# 4                NaN                  NaN                     NaN
#
#    CPI.Average          State  Total (millions of dollars)  \
# 0          NaN  United States                     $547,039
# 1          NaN  United States                     $547,039
# 2          NaN  United States                     $547,039
# 3          NaN  United States                     $547,039
# 4          NaN  United States                     $547,039
#
#   Per Capita (dollars) Percentage of General Revenue  \
# 0               $1,667                         16.6%
# 1               $1,667                         16.6%
# 2               $1,667                         16.6%
# 3               $1,667                         16.6%
# 4               $1,667                         16.6%
#
#   Percentage of Personal Income
# 0                          3.1%
# 1                          3.1%
# 2                          3.1%
# 3                          3.1%
# 4                          3.1%
#
# [5 rows x 22 columns]

# %%
dis.head()
# Out:
#                            loc_full  Biological  Chemical  Coastal Storm  \
# 0  Abbeville County, South Carolina         2.0       NaN            NaN
# 1          Acadia Parish, Louisiana         2.0       NaN            2.0
# 2         Accomack County, Virginia         2.0       NaN            NaN
# 3                 Ada County, Idaho         2.0       NaN            NaN
# 4                Adair County, Iowa         2.0       NaN            NaN
#
#    Dam/Levee Break  Drought  Earthquake  Fire  Fishing Losses  Flood  ...  \
# 0              NaN      1.0         NaN   NaN             NaN    1.0  ...
# 1              NaN      NaN         NaN   NaN             NaN    3.0  ...
# 2              NaN      NaN         NaN   NaN             NaN    2.0  ...
# 3              NaN      NaN         NaN   1.0             NaN    2.0  ...
# 4              NaN      NaN         NaN   NaN             NaN    4.0  ...
#
#    Severe Ice Storm  Severe Storm(s)  Snow  Terrorist  Tornado  \
# 0               1.0              2.0   NaN        NaN      1.0
# 1               NaN              4.0   NaN        NaN      NaN
# 2               NaN              2.0   2.0        NaN      NaN
# 3               NaN              NaN   NaN        NaN      NaN
# 4               2.0              6.0   1.0        NaN      NaN
#
#    Toxic Substances  Tsunami  Typhoon  Volcano           state
# 0               NaN      NaN      NaN      NaN  South Carolina
# 1               NaN      NaN      NaN      NaN       Louisiana
# 2               NaN      NaN      NaN      NaN        Virginia
# 3               NaN      NaN      NaN      NaN           Idaho
# 4               NaN      NaN      NaN      NaN            Iowa
#
# [5 rows x 25 columns]

# %%
merge4 = merge3.merge(right=dis, how='outer', on='loc_full')

# %%
merge4
# Out:
#        RegionID   RegionName State_x                           Metro  \
# 0        6181.0     New York      NY                        New York
# 1       12447.0  Los Angeles      CA  Los Angeles-Long Beach-Anaheim
# 2       46298.0   Long Beach      CA  Los Angeles-Long Beach-Anaheim
# 3       45457.0     Glendale      CA  Los Angeles-Long Beach-Anaheim
# 4        5534.0    Lancaster      CA  Los Angeles-Long Beach-Anaheim
# ...         ...          ...     ...                             ...
# 18647       NaN          NaN     NaN                             NaN
# 18648       NaN          NaN     NaN                             NaN
# 18649       NaN          NaN     NaN                             NaN
# 18650       NaN          NaN     NaN                             NaN
# 18651       NaN          NaN     NaN                             NaN
#
#         CountyName  SizeRank  pct_change  2017-09  \
# 0           Queens       1.0    0.092089    483.0
# 1      Los Angeles       2.0    0.080575    432.0
# 2      Los Angeles      34.0    0.068866    425.0
# 3      Los Angeles     122.0    0.059937    483.0
# 4      Los Angeles     138.0    0.119016    149.0
# ...            ...       ...         ...      ...
# 18647          NaN       NaN         NaN      NaN
# 18648          NaN       NaN         NaN      NaN
# 18649          NaN       NaN         NaN      NaN
# 18650          NaN       NaN         NaN      NaN
# 18651          NaN       NaN         NaN      NaN
#
#                            loc_full dest_state  ...  Severe Ice Storm  \
# 0                        Queens, NY        NaN  ...               NaN
# 1                   Los Angeles, CA        NaN  ...               NaN
# 2                   Los Angeles, CA        NaN  ...               NaN
# 3                   Los Angeles, CA        NaN  ...               NaN
# 4                   Los Angeles, CA        NaN  ...               NaN
# ...                             ...        ...  ...               ...
# 18647          Yuma County, Arizona        NaN  ...               NaN
# 18648         Yuma County, Colorado        NaN  ...               NaN
# 18649          Zapata County, Texas        NaN  ...               NaN
# 18650          Zavala County, Texas        NaN  ...               NaN
# 18651  Ziebach County, South Dakota        NaN  ...               NaN
#
#       Severe Storm(s) Snow  Terrorist  Tornado  Toxic Substances  Tsunami  \
# 0                 NaN  NaN        NaN      NaN               NaN      NaN
# 1                 NaN  NaN        NaN      NaN               NaN      NaN
# 2                 NaN  NaN        NaN      NaN               NaN      NaN
# 3                 NaN  NaN        NaN      NaN               NaN      NaN
# 4                 NaN  NaN        NaN      NaN               NaN      NaN
# ...               ...  ...        ...      ...               ...      ...
# 18647             1.0  NaN        NaN      NaN               NaN      NaN
# 18648             1.0  NaN        NaN      1.0               NaN      NaN
# 18649             1.0  NaN        NaN      NaN               NaN      NaN
# 18650             3.0  NaN        NaN      NaN               NaN      NaN
# 18651            10.0  2.0        NaN      NaN               NaN      NaN
#
#       Typhoon Volcano       state_y
# 0         NaN     NaN           NaN
# 1         NaN     NaN           NaN
# 2         NaN     NaN           NaN
# 3         NaN     NaN           NaN
# 4         NaN     NaN           NaN
# ...       ...     ...           ...
# 18647     NaN     NaN       Arizona
# 18648     NaN     NaN      Colorado
# 18649     NaN     NaN         Texas
# 18650     NaN     NaN         Texas
# 18651     NaN     NaN  South Dakota
#
# [18652 rows x 46 columns]

# %%
merge4.to_csv('giant_merge.csv')
